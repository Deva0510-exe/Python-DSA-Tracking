# %%
##Comparision Operator
## Equal too ==
a=10
b=10

print(a==b)
# Out:
# True

# %%
##Not Equal too
str1="Krish"
str2="Naik"

str1!=str2
# Out:
# True

# %%
##Greater than 
a=10
b=50 

print(b>a)
# Out:
# True

# %%
## Less than
a=10
b=50

a<b
# Out:
# True

# %%
##Greater than Equal too
a=50
b=60

b>=a
# Out:
# True

# %%
## Less than equal too
a=10 
b=10

b<=10
# Out:
# True

# %%
#### Logical Operator

# %%
## AND Operator
a=True
b=True

print(a and b)
# Out:
# True

# %%
## OR Operator 
a=False
b=True

print(a or b)
# Out:
# True

# %%
## NOT Operator
a=False
print(not a)
# Out:
# True
