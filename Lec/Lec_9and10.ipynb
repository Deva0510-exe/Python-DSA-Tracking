# %%
##Declearing and Assigning the Variable 

Age=20
height="5'11"
name="Deva"
is_student=True
##Printing the Variable
print("Age:",Age)
print("height:",height)
print("Name:",name)
# Out:
# Age: 20
# height: 5'11
# Name: Deva

# %%
##Case Sensetive in nature
name="Krish"
Name="Naik"

name==Name
# Out:
# False

# %%
##Understanding Variable Datatype
##Type Conversion

age=25 
print(type(age))

##convering the type
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
##Dynamic Typing 
##Changing the type of data and while the program is executing

var=10#int
print(var,type(var))

var="Hello"
print(var,type(var))

var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
##Simple Calculator
num1 = float(input("Enter First Number as input:"))
num2 = float(input("Enter Second Number as input:"))

sum=num1+num2
difference= num1-num2
product=num1*num2
quotient=num1/num2

print("Sum:",sum)
print("Difference",difference)
print("Multiplication",product)
print("Division",quotient)
# Out:
# Sum: 77.0
# Difference -37.0
# Multiplication 1140.0
# Division 0.3508771929824561
